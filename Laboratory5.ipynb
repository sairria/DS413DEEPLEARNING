# %% [markdown]
# ### LABORATORY TASK # 5 ###
#
# **Name** : Airyll H. Sanchez
#
# **Section**: DS4A
#
# **Date**: September 3, 2025

# %% [markdown]
# ![image.png](attachment:4b13c89e-e1ed-4f5c-8266-a8d7dca0b002.png)

# %% [markdown]
# 1. Perform Standard Imports

# %%
import torch
import numpy as np
import sys
import random

# %% [markdown]
# ![image.png](attachment:2ffc889f-aedd-4314-a2b1-bc9f2b72f82e.png)

# %%
def set_seed(seeed: int) -> None:
    torch.manual_sed(seed)
    random.seed(seeed)
    np.random.seed(seeed)

# %% [markdown]
# ![image.png](attachment:dff4b118-e861-4336-a4c0-679fdb77c33d.png)

# %%
def set_seed(seed):
    np.random.seed(seed)

set_seed(42)
arr = np.random.randint(0, 5, 6)
print (arr)
# Out:
# [3 4 2 4 4 1]

# %% [markdown]
# ![image.png](attachment:52ef30e2-fc29-4985-9a66-b86fbe045d42.png)

# %%
x = torch.from_numpy(arr)
print("PyTorch tensor:", x)
# Out:
# PyTorch tensor: tensor([3, 4, 2, 4, 4, 1], dtype=torch.int32)

# %% [markdown]
# ![image.png](attachment:492da01f-914e-47b7-8d36-b0e60e36b213.png)

# %%
dt = x.type(torch.int64)
print(dt)
print(dt.dtype)
# Out:
# tensor([3, 4, 2, 4, 4, 1])
# torch.int64

# %% [markdown]
# ![image.png](attachment:9724dc1f-3a71-4053-a019-02360cd3cfd2.png)

# %%
x = torch.arange(6).reshape(3,2)
print(x)
# Out:
# tensor([[0, 1],
#         [2, 3],
#         [4, 5]])

# %%
x = x.reshape(3,2)
print("Reshaped tensor:\n", x)
print("New shape:", x.shape)
# Out:
# Reshaped tensor:
#  tensor([[0, 1],
#         [2, 3],
#         [4, 5]])
# New shape: torch.Size([3, 2])

# %% [markdown]
# ![image.png](attachment:7dc03b72-7fb2-4236-9baa-c6e1d15a3288.png)

# %%
x[:,1]
# Out:
# tensor([1, 3, 5])

# %% [markdown]
# ![image.png](attachment:ea7e1393-1b37-4506-a5a2-176cdee29500.png)

# %%
squared_x = x ** 2
print("Squared tensor:\n", squared_x)
# Out:
# Squared tensor:
#  tensor([[ 0,  1],
#         [ 4,  9],
#         [16, 25]])

# %% [markdown]
#  ![image.png](attachment:83e8a9bc-0d23-4a3b-81f6-c11effb17ca5.png)

# %%
set_seed(42)
y = torch.randint(low=0,high=5,size=(2,3),dtype= torch.int64)
y
# Out:
# tensor([[0, 4, 0],
#         [3, 3, 4]])

# %% [markdown]
# ![image.png](attachment:8c414e85-8785-401f-9647-10c42c44d7e6.png)

# %%
print(torch.mm(x,y))
# Out:
# tensor([[ 3,  3,  4],
#         [ 9, 17, 12],
#         [15, 31, 20]])
